# %%
import os
import pandas as pd

# %%
path="Jobs Links 26 sep to 02 oct/Linkedin_jobs_of_26_september_by_24_hours_23_pages"

# %%
dir_list = os.listdir(path)
dir_list
# Out:
# ['linkedin_jobs_page10_26_sep_25.csv',
#  'linkedin_jobs_page11_26_sep_25.csv',
#  'linkedin_jobs_page12_26_sep_25.csv',
#  'linkedin_jobs_page13_26_sep_25.csv',
#  'linkedin_jobs_page14_26_sep_25.csv',
#  'linkedin_jobs_page15_26_sep_25.csv',
#  'linkedin_jobs_page16_26_sep_25.csv',
#  'linkedin_jobs_page17_26_sep_25.csv',
#  'linkedin_jobs_page18_26_sep_25.csv',
#  'linkedin_jobs_page19_26_sep_25.csv',
#  'linkedin_jobs_page1_26_sep_25.csv',
#  'linkedin_jobs_page20_26_sep_22.csv',
#  'linkedin_jobs_page21_26_sep_20.csv',
#  'linkedin_jobs_page22_26_sep_25.csv',
#  'linkedin_jobs_page23_26_sep_19.csv',
#  'linkedin_jobs_page2_26_sep_25.csv',
#  'linkedin_jobs_page3_26_sep_25.csv',
#  'linkedin_jobs_page4_26_sep_25.csv',
#  'linkedin_jobs_page5_26_sep_25.csv',
#  'linkedin_jobs_page6_26_sep_25.csv',
#  'linkedin_jobs_page7_26_sep_25.csv',
#  'linkedin_jobs_page8_26_sep_25.csv',
#  'linkedin_jobs_page9_26_sep_25.csv']

# %%
len(dir_list)
# Out:
# 23

# %%
type(dir_list)
# Out:
# list

# %%
dir_list.sort()

# %%
dir_list[0].split('page')[1].split('_')[0]
# Out:
# '10'

# %%
int(dir_list[0].split('page')[1].split('_')[0])
# Out:
# 10

# %%
file_names=[]
for i in range(1,len(dir_list)+1):
    for file in dir_list:
        if int(file.split('page')[1].split('_')[0])==i:
            file_names.append(file)

# %%
file_names
# Out:
# ['linkedin_jobs_page1_26_sep_25.csv',
#  'linkedin_jobs_page2_26_sep_25.csv',
#  'linkedin_jobs_page3_26_sep_25.csv',
#  'linkedin_jobs_page4_26_sep_25.csv',
#  'linkedin_jobs_page5_26_sep_25.csv',
#  'linkedin_jobs_page6_26_sep_25.csv',
#  'linkedin_jobs_page7_26_sep_25.csv',
#  'linkedin_jobs_page8_26_sep_25.csv',
#  'linkedin_jobs_page9_26_sep_25.csv',
#  'linkedin_jobs_page10_26_sep_25.csv',
#  'linkedin_jobs_page11_26_sep_25.csv',
#  'linkedin_jobs_page12_26_sep_25.csv',
#  'linkedin_jobs_page13_26_sep_25.csv',
#  'linkedin_jobs_page14_26_sep_25.csv',
#  'linkedin_jobs_page15_26_sep_25.csv',
#  'linkedin_jobs_page16_26_sep_25.csv',
#  'linkedin_jobs_page17_26_sep_25.csv',
#  'linkedin_jobs_page18_26_sep_25.csv',
#  'linkedin_jobs_page19_26_sep_25.csv',
#  'linkedin_jobs_page20_26_sep_22.csv',
#  'linkedin_jobs_page21_26_sep_20.csv',
#  'linkedin_jobs_page22_26_sep_25.csv',
#  'linkedin_jobs_page23_26_sep_19.csv']

# %%
path+'/'+file_names[0]
# Out:
# 'Jobs Links 26 sep to 02 oct/Linkedin_jobs_of_26_september_by_24_hours_23_pages/linkedin_jobs_page1_26_sep_25.csv'

# %%
df1=pd.read_csv(path+'/'+file_names[0])

# %%
df1
# Out:
#                                             Job Title  \
# 0                             LinkedIn Data Extractor
# 1                                It Management Intern
# 2                              SQL Database Developer
# 3                     Business Intelligence Developer
# 4                          Web Developer - Internship
# 5   Research Analyst for Business Subjects (Office...
# 6                        Performance Marketing Intern
# 7                                   Sr. SDET Engineer
# 8                                  Associate Engineer
# 9                            Fresh Graduate Engineers
# 10                           Fraud Monitoring Officer
# 11                            Business System Analyst
# 12                         Research Analyst - Finance
# 13                                          HR Intern
# 14     Alfa Origin is looking for sales and HR Intern
# 15                        Sales Operations Specialist
# ...

# %%
df2=pd.read_csv(path+'/'+file_names[1])
df2
# Out:
#                                     Job Title  \
# 0                           Software Engineer
# 1                   Machine Learning Engineer
# 2                       SQL Database Engineer
# 3                   Junior Business Developer
# 4                      Human Resources Intern
# 5                        Antifraud Specialist
# 6                  Management Trainee Officer
# 7              Jr Business Developer (Upwork)
# 8       Software Engineer - Product Operation
# 9   International Procurement/Sourcing Intern
# 10                               Data Analyst
# 11                    Human Resources Trainee
# 12            Office Administrative Assistant
# 13                            Staff Assistant
# 14            Business Development Specialist
# 15             Business Development Executive
# 16                                    IT Jobs
# 17                 Technical Business Analyst
# 18       Senior Business Intelligence Analyst
# ...

# %%
df_list = [df1, df2]

# %%
df_concat = pd.concat(df_list,ignore_index=True)

# %%
df_concat
# Out:
#                                             Job Title  \
# 0                             LinkedIn Data Extractor
# 1                                It Management Intern
# 2                              SQL Database Developer
# 3                     Business Intelligence Developer
# 4                          Web Developer - Internship
# 5   Research Analyst for Business Subjects (Office...
# 6                        Performance Marketing Intern
# 7                                   Sr. SDET Engineer
# 8                                  Associate Engineer
# 9                            Fresh Graduate Engineers
# 10                           Fraud Monitoring Officer
# 11                            Business System Analyst
# 12                         Research Analyst - Finance
# 13                                          HR Intern
# 14     Alfa Origin is looking for sales and HR Intern
# 15                        Sales Operations Specialist
# ...

# %%
df3=pd.read_csv(path+'/'+file_names[2])
df3
# Out:
#                                             Job Title  \
# 0   Database Operations and Administration Specialist
# 1                        Business Development Manager
# 2                      Business Development Executive
# 3                        Business Development Officer
# 4            Python Developer with Data Science Focus
# 5             E-Commerce and Digital marketing Expert
# 6                        Business Development Officer
# 7                                      Budget Analyst
# 8                            HR Executive -Operations
# 9                                      Odoo Developer
# 10                                         iOS Intern
# 11                    Customer Support Representative
# 12                                      Web Developer
# 13                                  Upwork Specialist
# 14                                   Freelance Bidder
# 15                                 SOFTWARE DEVELOPER
# ...

# %%
df_concat_=pd.concat([df_concat,df3],ignore_index=True)
df_concat_
# Out:
#                               Job Title  \
# 0               LinkedIn Data Extractor
# 1                  It Management Intern
# 2                SQL Database Developer
# 3       Business Intelligence Developer
# 4            Web Developer - Internship
# ..                                  ...
# 70       Business Development Executive
# 71  Business Development Representative
# 72       Business Development Executive
# 73         Customer Project Coordinator
# 74        Customer Experience Executive
#
#                                              Job Link
# 0   https://www.linkedin.com/jobs/view/3727054368/...
# 1   https://www.linkedin.com/jobs/view/3723395858/...
# 2   https://www.linkedin.com/jobs/view/3727034665/...
# 3   https://www.linkedin.com/jobs/view/3727029273/...
# 4   https://www.linkedin.com/jobs/view/3727034696/...
# ..                                                ...
# 70  https://www.linkedin.com/jobs/view/3723355200/...
# ...

# %%
df_concat2=pd.concat([df3,df3],ignore_index=True)
df_concat2
# Out:
#                                             Job Title  \
# 0   Database Operations and Administration Specialist
# 1                        Business Development Manager
# 2                      Business Development Executive
# 3                        Business Development Officer
# 4            Python Developer with Data Science Focus
# 5             E-Commerce and Digital marketing Expert
# 6                        Business Development Officer
# 7                                      Budget Analyst
# 8                            HR Executive -Operations
# 9                                      Odoo Developer
# 10                                         iOS Intern
# 11                    Customer Support Representative
# 12                                      Web Developer
# 13                                  Upwork Specialist
# 14                                   Freelance Bidder
# 15                                 SOFTWARE DEVELOPER
# ...

# %%
df=None
df_concat3=pd.concat([df,df1],ignore_index=True)
df_concat3
# Out:
#                                             Job Title  \
# 0                             LinkedIn Data Extractor
# 1                                It Management Intern
# 2                              SQL Database Developer
# 3                     Business Intelligence Developer
# 4                          Web Developer - Internship
# 5   Research Analyst for Business Subjects (Office...
# 6                        Performance Marketing Intern
# 7                                   Sr. SDET Engineer
# 8                                  Associate Engineer
# 9                            Fresh Graduate Engineers
# 10                           Fraud Monitoring Officer
# 11                            Business System Analyst
# 12                         Research Analyst - Finance
# 13                                          HR Intern
# 14     Alfa Origin is looking for sales and HR Intern
# 15                        Sales Operations Specialist
# ...

# %%
df_concat=None
for file in file_names:
    df=pd.read_csv(path+'/'+file)
    df_concat=pd.concat([df_concat,df],ignore_index=True)

# %%
df_concat
# Out:
#                            Job Title  \
# 0            LinkedIn Data Extractor
# 1               It Management Intern
# 2             SQL Database Developer
# 3    Business Intelligence Developer
# 4         Web Developer - Internship
# ..                               ...
# 556       Sr. React Native developer
# 557                      2D Animator
# 558                Interior Designer
# 559            Sr. Angular Developer
# 560         Senior Angular Developer
#
#                                               Job Link
# 0    https://www.linkedin.com/jobs/view/3727054368/...
# 1    https://www.linkedin.com/jobs/view/3723395858/...
# 2    https://www.linkedin.com/jobs/view/3727034665/...
# 3    https://www.linkedin.com/jobs/view/3727029273/...
# 4    https://www.linkedin.com/jobs/view/3727034696/...
# ..                                                 ...
# 556  https://www.linkedin.com/jobs/view/3728033193/...
# 557  https://www.linkedin.com/jobs/view/3728149502/...
# ...

# %%
file_names[0].split('_')[5].split('.')[0]
# Out:
# '25'

# %%
total_records=0
for file in file_names:
    total_records=total_records+int(file.split('_')[5].split('.')[0])

# %%
total_records
# Out:
# 561

# %%
folder_path='Concatenated files/1st Week 26 Sep-02 Oct/'
folder_path
# Out:
# 'Concatenated files/1st Week 26 Sep-02 Oct/'

# %%
df_concat.to_csv(folder_path+'Linkedin_Job_Links_26-Sep-2023_561-jobs_23-pages.csv')
